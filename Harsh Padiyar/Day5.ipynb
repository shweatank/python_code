# %% [markdown]
# List Comprehension

# %% [raw]
# # Syntax
# [exp/stmt for var in seq (optional Condition )]

# %%
a=[1,2,3,4,5]
b=[]
for x in a:
    b.append(x*x)
print(b)

print([x*x for x in a]) 

print([x for x in a if not x%2])
# Out:
# [1, 4, 9, 16, 25]
# [1, 4, 9, 16, 25]
# [2, 4]

# %%
a=[1,2,4,6]
b=[3,4,6,5]
print([x+y for x in a for y in b if x+y!=7])
# print([x+y for x in a for y in b if x+y!=7])
# Out:
# [4, 5, 6, 5, 6, 8, 8, 10, 9, 9, 10, 12, 11]

# %%
a=[1,2,4,6]
b=[3,4,6,5]
print([[x+y for x in a if x+y!=7] for y in b])
# Out:
# [[4, 5, 9], [5, 6, 8, 10], [8, 10, 12], [6, 9, 11]]

# %%
a=[1,2,4,6]
b=[3,4,6,5]
print([[x1+y1 for x1 in a if x1+y1!=7] for y1 in b ])
# Out:
# [[4, 5, 9], [5, 6, 8, 10], [8, 10, 12], [6, 9, 11]]

# %%
a1=-1
b1="positive" if a1<0 else "negative"
print(b1)
# Out:
# positive

# %%
a1=5
b1=a1*-1 if a1>0 else a1*1 
print(b1)
# Out:
# -5

# %%
a=[10,20,[30,40,50],60,[70]]
b=[ele for x in a for ele in(x if isinstance(x,list) else[x])]
c=[x if isinstance(x,int) else [y for y in x] for x in a ]

print(b)
print(c)
# Out:
# [10, 20, 30, 40, 50, 60, 70]
# [10, 20, [30, 40, 50], 60, [70]]

# %%
from time import time

t1=time()

for x in range(1000):
    c.append(x)
print(time()-t1)
# Out:
# 9.655952453613281e-05

# %%
from time import time

t1=time()

c=[x in range(1000)]
print(time()-t1)
# Out:
# 0.00011706352233886719

# %% [raw]
# Take list of number 2, 3, 5,7,9,12,15,16,17 if a number is multiple by 3 square it if the number is multiple by 5 cube it and if
# multiple by both igmore the value otherwise add the value of 3 to the number.

# %%
a=[2,3,5,7,9,12,15,16,17]

print([x**2 if x%3==0 else x**3 if x%5==0 else x+3 for x in a if not(x%3==0 and x%5==0)])
# Out:
# [5, 9, 125, 10, 81, 144, 19, 20]

# %%
print([[x+y for y in range(1,4) if x != y] for x in range(3)])
# Out:
# [[1, 2, 3], [3, 4], [3, 5]]

# %%
# [[1, 2, 3], [3, 4], [3, 5]] flattern the list and ignore the nested list which contains 4 
a=[[x+y for y in range(1,4) if x!=y ] for x in range(3)]
b=[x for y in [x for x in a if 4 not in x] for x in y]
print(b)
# Out:
# [1, 2, 3, 3, 5]

# %%
a=[None]
b=[]
print(bool(a))
print(bool(b))
# Out:
# True
# False

# %%
a=[10,20]
del a[0]
if a :
    print("first")
del a[0]
if a :
    print("Second")
# Out:
# first

# %%
list(True) ->  X
# Out:
#   Cell In[17], line 1
#     list(True) ->  X
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# List Methods

# %%
print(dir([]))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
a.append.__doc__
# Out:
# 'Append object to the end of the list.'

# %%
a.extend.__doc__
# Out:
# 'Extend list by appending elements from the iterable.'

# %%
a.insert.__doc__
# Out:
# 'Insert object before index.'

# %%
print(help(a.append))
# Out:
# Help on built-in function append:
#
# append(object, /) method of builtins.list instance
#     Append object to the end of the list.
#
# None

# %%
a=[10,20,30]
a.append(100)
print(a.append(100))
print(a)
# Out:
# None
# [10, 20, 30, 100, 100]

# %%
a.pop.__doc__
# Out:
# 'Remove and return item at index (default last).\n\nRaises IndexError if list is empty or index is out of range.'

# %%
print(a.pop(1))
# Out:
# 20

# %%
print(a)
# Out:
# [10, 30, 100, 100]

# %%
b=[100,200]
for x in b:
    a.append(x)
    # print(a)
print(a)
# Out:
# [10, 30, 100, 100, 100, 200]

# %%
a=[10,20,30,40,50]
b=[]
print("Concat:",a+b)
print("Multiply",a*2)
# Out:
# Concat: [10, 20, 30, 40, 50]
# Multiply [10, 20, 30, 40, 50, 10, 20, 30, 40, 50]

# %%
print(ord("A"))
print(ord("@"))
print(ord("0"))
print(ord("Z"))
# Out:
# 65
# 64
# 48
# 90

# %%
a=[10,20,30,40,50]
b=[]
print(a>b)
# Out:
# True

# %%
a=[2,3,4]
b=[2,3,4]
print(a==b)
# Out:
# True

# %%
a=[2,3,4]
b=[5]
print(a<b)
# Out:
# True

# %%
a=[12,3,4]
b=[5]
print(a<b)
# Out:
# False

# %%
a=[[2,4],[4,5]]
b=[10,20]
print(a<b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 a=[[2,4],[4,5]]
#       2 b=[10,20]
# ----> 3 print(a<b)
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
a=[[2,4],[4,5]]
b=[[1,5,6],[20]]
print(a>b)
# Out:
# True

# %%
a=[[2,3],[4,5]]
b=[[2,3],[2]]
print(a>b)
# Out:
# True

# %%
a = ["raghu","vedansh",]
b = [ "mirafra", "intel"]
print(a>b)
# Out:
# True

# %%
a = ["Raghu","vedansh",]
b = [ "mirafra", "intel"]
print(a>b)
# Out:
# False

# %%
a = ["~Raghu","vedansh",]
b = [ "mirafra", "intel"]
print(a>b)
# Out:
# True

# %% [markdown]
# Logical

# %%
print([2] and [3,4])
# Out:
# [3, 4]

# %%
print([] and [3,4])
# Out:
# []

# %%
print(0 and [3,4])
# Out:
# 0

# %%
print(22 and [3,4])
# Out:
# [3, 4]

# %%
print(bool(22))
# Out:
# True

# %%
print(not[])
# Out:
# True

# %% [markdown]
# Membership

# %%
print(dir([]))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
a = [[10, 20 ,30], 30, 40]
print(20 in a)
# Out:
# False

# %%
print(30 in a)
# Out:
# True

# %%
print([10,20,30] in a)
# Out:
# True

# %%
print([10,20] not in a)
# Out:
# True

# %% [markdown]
# Identity Operator

# %%
print(2 is 2)
# Out:
# True
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_118275/2709023400.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   print(2 is 2)

# %%
print(1000 is 1000)
# Out:
# True
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_118275/1281767823.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   print(1000 is 1000)

# %%
a = 1000
b = 1000
print(a is b)
# Out:
# False

# %%
print(id(a), id(b))
# Out:
# 124696858560528 124696858561520

# %%
a = 2
b = 2
print(a is b)
# Out:
# True

# %%
a =[]
b= []
print(a is b) #2 new list is created
# Out:
# False

# %%
a = ()
b = ()
print( a is b)
# Out:
# True

# %%
a1 = 7

# %%
print(id(a1))
del a1
# Out:
# 124697682379184

# %%
b1 = 7
print(id(b1))
# Out:
# 124697682379184

# %%
a = (10, 20, 30)
b = (10, 20, 30)
print(id(a), id(b))
# Out:
# 124696858829120 124696857203456

# %%
a = [10,20]
b = [10,20]
c = a
print(a is c)
print(a is b)
# Out:
# True
# False

# %% [raw]
# Copy Types
# * Instance - Reference copy
# * Shallow Copy
# * Deep Copy
#
# Shortcut in Python
#
# Shallow copy: lst[:] or list(lst)
#
# Deep copy: copy.deepcopy(lst)

# %%
import copy

# %% [raw]
# shallow Copy - copy()
# deep copy - deepcopy()

# %%
from copy import copy, deepcopy
a = [ 10, 20, [10, 20, 30], "hello"]
b = a
c = copy(a)
d = deepcopy(a)
a[2][1] = 200
a[2] = [10,20]

# %% [markdown]
# Tuple

# %%
a = (10,20,30)
# a[1] = 50
print(a)
# Out:
# (10, 20, 30)

# %%
from sys import getsizeof as gs
a = [10,20,30]
b = (10,20,30)

# %%
gs(a)
# Out:
# 88

# %%
gs(b)
# Out:
# 64

# %%
a.append(40)
gs(a)
# Out:
# 88

# %%
a.append(40)
gs(a)
# Out:
# 120

# %%
a.append(40)
gs(a)
# Out:
# 120

# %%
a.append(40)
gs(a)
# Out:
# 120

# %%
a.append(40)
gs(a)
# Out:
# 120

# %%
a = []
b = ()
print(gs(a), gs(b))
# Out:
# 56 40

# %%
a=(1,2,[20,40,20],50,(10,20,30))
a[2][2]=10000
print(a)
# Out:
# (1, 2, [20, 40, 10000], 50, (10, 20, 30))

# %%
a=(1,2,[20,40,20],50,(10,20,30))
# a[4][2]=10000
print(a)  #Error
# Out:
# (1, 2, [20, 40, 20], 50, (10, 20, 30))

# %% [markdown]
# Sets

# %%
s={}
s1={10,20,30}
print(type(s))
print(type(s1))
# Out:
# <class 'dict'>
# <class 'set'>

# %%
a=set((10,20))
b=set([10,20])
print(type(a))
print(a)
print(type(b))
print(b)
# Out:
# <class 'set'>
# {10, 20}
# <class 'set'>
# {10, 20}

# %%
a=()
# print(id(a))
b=set(a)
# print(id(b))
# print(id(a))
b.add(10)
print(b)
b.add(20)
print(b)
b.add(5)
print(b)
print(b)
b.add("Deepak")
print(b)
# Out:
# {10}
# {10, 20}
# {10, 20, 5}
# {10, 20, 5}
# {10, 20, 5, 'Deepak'}
