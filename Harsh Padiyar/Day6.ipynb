# %%
a ={1,2,3}
print(dir(a))
# Out:
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
# b = {x**2 for x in range(3)}
# print(b)

# %%
b = {x**2 for x in a}
print(b)
# Out:
# {1, 4, 9}

# %%
b.pop(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 b.pop(2)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
b.pop()
# Out:
# 1

# %%
b
# Out:
# {4, 9}

# %%
b= {1, 4, 9}

# %%
a + b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 a + b
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 9}

# %%
c = a.union(b)
print(c)
# Out:
# {1, 2, 3, 4, 9}

# %%
a.intersection(b)
# Out:
# {1}

# %%
a - b
# Out:
# {2, 3}

# %%
a.difference(b)
# Out:
# {2, 3}

# %%
b - a
# Out:
# {4, 9}

# %%
a & b
# Out:
# {1}

# %%
a
# Out:
# {1, 2, 3}

# %%
b
# Out:
# {1, 4, 9}

# %%
c = a.difference_update(b)
print(c)
# Out:
# None

# %%
a
# Out:
# {2, 3}

# %%
b
# Out:
# {1, 4, 9}

# %%
a > b
# Out:
# False

# %%
a = {1,2}
b = {1,2,5}

# %%
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a.issubset(b)
# Out:
# True

# %%
if not a-b:
    print("done")
# Out:
# done

# %% [markdown]
# Dictionay

# %%
d = {1:2, 3:4}

# %%
for x in d:
    print(x)
# Out:
# 1
# 3

# %%
for x in d.keys():
    print(x)
# Out:
# 1
# 3

# %%
for x in d.values():
    print(x)
# Out:
# 2
# 4

# %%
for x in d.items():
    print(x)
# Out:
# (1, 2)
# (3, 4)

# %%
list(d.items())
# Out:
# [(1, 2), (3, 4)]

# %%
for a,b in d.items():
    print(f"key is {a} and value is {b}")
# Out:
# key is 1 and value is 2
# key is 3 and value is 4

# %%
school = { "2": {"marks": {"Raghu": 100, "Vedansh": 95, "vivid": 95}}, "3": {}}

# %%
school["2"]["marks"]["Vedansh"]
# Out:
# 95

# %%
# for x,y in scholl.items():
#     if y:

# %%
print(d)
# Out:
# {1: 2, 3: 4}

# %%
d[5] = 6
print(d)
# Out:
# {1: 2, 3: 4, 5: 6}

# %%
d[5]=10

# %%
d1 = {1:2, 1:3, 1:4}
print(len(d1))
# Out:
# 1

# %%
print(d1)
# Out:
# {1: 4}

# %%
classes = { "python": {"Nag":["05:00 AM", "07:00 AM", "04:00 PM"], "Samba": ["05:00 PM", "09:00 AM"]}, "CPP": {"Prasanth": ["10:00 AM", "02:00 PM"]}}

# %%
print(classes)
# Out:
# {'python': {'Nag': ['05:00 AM', '07:00 AM', '04:00 PM'], 'Samba': ['05:00 PM', '09:00 AM']}, 'CPP': {'Prasanth': ['10:00 AM', '02:00 PM']}}

# %%
print(classes.get("python"))
# Out:
# {'Nag': ['05:00 AM', '07:00 AM', '04:00 PM'], 'Samba': ['05:00 PM', '09:00 AM']}

# %%
print(len(""))
# Out:
# 0

# %%
print(classes.get("python", 0))
# Out:
# {'Nag': ['05:00 AM', '07:00 AM', '04:00 PM'], 'Samba': ['05:00 PM', '09:00 AM']}

# %%
print(classes.get("java"))
# Out:
# None

# %%
count =0 
for times in classes.get("python", {}).values():
    print(count)
# Out:
# 0
# 0

# %%
d1 = {1:2, 3:4}
d2 = {1:4, 5:6}
d1.update(d2)
print(d1)
# Out:
# {1: 4, 3: 4, 5: 6}

# %% [markdown]
# String

# %%
a = "12"
b = 12
print(a+b) # we cannot add intger
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 3
#       1 a = "12"
#       2 b = 12
# ----> 3 print(a+b) # we cannot add intger
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = "12"
b = "22"
print(a+b)
# Out:
# 1222

# %%
a = '1@abc'
print(type(a))
# Out:
# <class 'str'>

# %%
a = " "
print(bool(a)) # true because it contain a 1 speacial charactor which is a space.
# Out:
# True

# %%
a = "This is the python class\nThis class start at 09:00 AM"
print(a)
# Out:
# This is the python class
# This class start at 09:00 AM

# %%
a = "This is the python class\\nThis class start at 09:00 AM"
print(a)
# Out:
# This is the python class\nThis class start at 09:00 AM

# %%
a = "This is the "python" class\nThis class start at 09:00 AM"
print(a)
# Out:
#   Cell In[100], line 1
#     a = "This is the "python" class\nThis class start at 09:00 AM"
#                       ^
# SyntaxError: invalid syntax

# %%
a = "This is the \"python\" class\nThis class start at 09:00 AM"
print(a)
# Out:
# This is the "python" class
# This class start at 09:00 AM

# %%
a = r"This is the \"python\" class\nThis class start at 09:00 AM\n Nag will taking the class"
print(a)
# Out:
# This is the \"python\" class\nThis class start at 09:00 AM\n Nag will taking the class

# %%
a = "This is the \"python\" class\nThis class start at 09:00 AM\n Nag will taking the class"
print(a)
# Out:
# This is the "python" class
# This class start at 09:00 AM
#  Nag will taking the class

# %%
classes ='{ "python": {"Nag":["05:00 AM", "07:00 AM", "04:00 PM"], "Samba": ["05:00 PM", "09:00 AM"]}, "CPP": {"Prasanth": ["10:00 AM", "02:00 PM"]}}'
print(classes)
# Out:
# { "python": {"Nag":["05:00 AM", "07:00 AM", "04:00 PM"], "Samba": ["05:00 PM", "09:00 AM"]}, "CPP": {"Prasanth": ["10:00 AM", "02:00 PM"]}}

# %%
print(type(classes))
# Out:
# <class 'str'>

# %%
import json

# %%
d = json.loads(classes)
print(type(d))
# Out:
# <class 'dict'>

# %%
names = [("raghu",30), ("vedansh",50)]
for x in names:
    print(f"the data of {x[0]} is {x[1]}")
# Out:
# the data of raghu is 30
# the data of vedansh is 50

# %%
names = [("raghu",30), ("vedansh",50)]
b = []
for x in names:
    b.append(f"the data of {x[0]} is {x[1]}")

# %%
print(b)
# Out:
# ['the data of raghu is 30', 'the data of vedansh is 50']

# %%
b[0][0]= "s"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 b[0][0]= "s"
#
# KeyError: 0

# %%
b1 = "python"
for x in b1:
    print(x*2)
# Out:
# pp
# yy
# tt
# hh
# oo
# nn

# %%
"python" and "nag"
# Out:
# 'nag'

# %%
'' and "nag"
# Out:
# ''

# %% [markdown]
# Strings Methods

# %%
print(dir(a))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
a = 10

# %%
print(a)
# Out:
# 10

# %%
print(f"{a}")
# Out:
# 10

# %%
print(f"{a:>8}")
# Out:
#       10

# %%
print(10)
print(100)
# Out:
# 10
# 100

# %%
print(f"{10:>3}")
print(f"{100:>3}")
# Out:
#  10
# 100

# %%
a = "This is python class"
a.center(100)
# Out:
# '                                        This is python class                                        '

# %%
a.ljust(100)
# Out:
# 'This is python class                                                                                '

# %%
a.rjust(100)
# Out:
# '                                                                                This is python class'

# %%
a.center(100, "@")
# Out:
# '@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@This is python class@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@'
