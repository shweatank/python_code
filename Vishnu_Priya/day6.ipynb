# %% [markdown]
# ### set :

# %%
a={1,2,3}
print(dir(a))
# Out:
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
# set comprehension
b={x for x in range(3)}
b

# %% [markdown]
# deleting particular element is not posibile in set\
# entire set can be deleted\
# pop and remove will work in set\
# pop will not take the index\
# pop will return the value. It will randomly removes the value\
# there is no indexing concept in the set\
#
# methods in set :\
# for adding the stuff add() function will be used \
# set operation :

# %%
# "+" operator in set 
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # "+" operator in set
# ----> 2 a+b
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
#union 
a.union(b)
# Out:
# {0, 1, 2, 3}

# %%
a
# Out:
# {1, 2, 3}

# %%
b
# Out:
# {0, 1, 2}

# %%
#intersection
a.intersection(b)
# Out:
# {1, 2}

# %%
print(b-a)
print(a-b)
print(a.difference(b))
# Out:
# {0}
# {3}
# {3}

# %% [markdown]
# difference between the intersection and intersection_update\
# Relation oparators with set

# %%
# Out:
# False

# %%
a={1,2}
b={1,2,3}
a<b # checking as a subset and suoerset
# Out:
# True

# %% [markdown]
# ### dectionary :

# %% [markdown]
# it is key value paired element \
# keys should be unique\
# values can be repeated\
# : are used to sep between the key and value\
# it uses the hashing concept for unique elements

# %%
d={1:2,3:4} #[2,4] 
d
# Out:
# {1: 2, 3: 4}

# %%
for i in d:
    print(i)
    print(d[i])
# Out:
# 1
# 2
# 3
# 4

# %%
to access the keys in dec : d.key()
to access the values in dec : d.values()
to access the items in dec : d.items()

# %%
for i in d.items():
    print(i)  #packed
# Out:
# (1, 2)
# (3, 4)

# %%
for a,b in d.items():
    print("a=",a,"b=",b) #unpacking
# Out:
# a= 1 b= 2
# a= 3 b= 4

# %%
school={"2":{"marks":{"Ram":100}}}
school
# Out:
# {'2': {'marks': {'Ram': 100}}}

# %%
school["2"]["marks"]["Ram"]
# Out:
# 100

# %%
school["Ram"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 school["Ram"]
#
# KeyError: 'Ram'

# %%
d1={1:1,1:2,1:3}
d1
# Out:
# {1: 3}

# %%
d1[1]="hello python"
print(d1)
print(dir(d1))
# Out:
# {1: 'hello python', 2: 'hello'}
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
#update function in the dectionary

# %%
len(d1) # as the key values are repeated the length of the dectionary is 1
# Out:
# 1

# %%
set(d1)
# Out:
# {1}

# %%
new={"Python":{"Nag":["6:00 AM", "9;00 AM","6:00 PM"]}}

# %% [markdown]
# ### string:
# + sequence of char
# + immutable data
# + string comprehension is not there
# + slicing will work
# + it uses  '', ""
# + cannot add string and num
# + "+"act as a concatenation
# + when the string conatins number we can change to integer
# + integer can convert to string
# + string to boolean
# + "\" in string have a special character
# + "r" it is for raw string. usually used in the regular exp
# + to handle with the large data we use xml and json
# + JSON encounter
# + tor e=make ud more readli then ther e wioo wn h
# + f string / formated string
# + it can traverse each element
# + ascii value------ord()
# + character--------chr()
# + relation operator will work by checking each and every element
# + logical operator will also work with string
# + memership operator
# + replace(), join(), strip(),slipt()

# %%
a=""
print(bool(a)) #empty string
# Out:
# False

# %%
a=" "
print(bool(a))
# Out:
# True

# %%
a="this is \"python\" language"
a
# Out:
# 'this is "python" language'

# %%
a=r"hello 'world' this is python class"
a
# Out:
# "hello 'world' this is python class"

# %%
name=[("arun",150),("raj",100)]
for i in name:
    print(f"name is {i[0]}")
# Out:
# name is arun
# name is raj

# %%
"python" and ""
# Out:
# ''

# %%
"python" and 'abc'
# Out:
# 'abc'

# %%
a="1234"
"4" in a
# Out:
# True

# %%
's' is 'o'
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_5045/137813839.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   's' is 'o'
# False

# %% [markdown]
# memory location will be different in the immutable. when the ref is diff

# %%
a=10
b=10
print(id(a))
print(id(b))
a=30
print(id(a))
# Out:
# 128437841822224
# 128437841822224
# 128437841822864

# %% [markdown]
# ### Methods:
# + replace()

# %% [markdown]
# how can we clear the unwanted data in python

# %%
a=" "
print(dir(a))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
# ...
