# %%
class Myclass:
    pass

# %% [markdown]
# class <classname>:
#     declaration of variables
#     declaration of methods

# %%
class Myclass:
    c = 30
    d = 40
    def __init__(self):
        print("i am from init")
        self.a=10
        self.b=20

# %%
i1=Myclass()
i2=Myclass()
# Out:
# i am from init
# i am from init

# %%
class Myclass:
    c = 30
    d = 40
    def __init__(self):
        print("i am from init")
        self.mp=10
        self.colour=20

# %%
print(i1.mp,i1.colour)
# Out:
# 10 20

# %%
class Bank:
    def __init__(self,pincode):
        self.pincode = pincode
        st_p =  self.pincode//100000
        if st_p <= 5:
            self.min_bal = 5000
        else:
            self.min_bal =1000
        self.bal = self.min_bal

# %%
class Bank:
    def __init__(self,pincode):
        self.pincode = pincode
        self.bal=0
        
        st_p =  self.pincode//100000
        if st_p <= 5:
            self.min_bal = 5000
        else:
            self.min_bal =1000
        self.bal = self.deposit(self.min_bal)
    def deposit(self,bal):
        self.bal +=bal
        return self.bal

# %%
b1 = Bank(500049)
print(b1.bal)
# Out:
# 5000

# %%
b1.deposit(10000)
# Out:
# 16000

# %% [markdown]
# self is a calling reference instance

# %%
class Bank:
    def __init__(self,pincode):
        print("self in init is {}".format(self))
        self.pincode = pincode
        self.bal=0
        st_p =  self.pincode//100000
        if st_p <= 5:
            self.min_bal = 5000
        else:
            self.min_bal =1000
        self.bal = self.deposit(self.min_bal)
    def deposit(self,bal):
        print("self in deposit is {}".format(self))
        self.bal +=bal
        return self.bal

# %%
b1=Bank(500049)
b2=Bank(500055)
# Out:
# self in init is <__main__.Bank object at 0x7871fe430ee0>
# self in deposit is <__main__.Bank object at 0x7871fe430ee0>
# self in init is <__main__.Bank object at 0x7871fe462a40>
# self in deposit is <__main__.Bank object at 0x7871fe462a40>

# %%
print(b1)

# %%
b1.deposit(1000)
# Out:
# self in deposit is <__main__.Bank object at 0x7871fe430ee0>
# 6000

# %%
class Bank:
    def __init__(self,pincode):
        print("self in init is {}".format(self))
        self.pincode = pincode
        self.bal=0
        st_p =  self.pincode//100000
        if st_p <= 5:
            self.min_bal = 5000
        else:
            self.min_bal =1000
        self.bal = self.deposit(self.min_bal)
    def deposit(abc,bal):
        print("self in deposit is {}".format(self))
        self.bal +=bal
        return self.bal

# %%
b1=Bank(500049)
# Out:
# self in init is <__main__.Bank object at 0x7871ff7a3520>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 b1=Bank(500049)
#
# Cell In[31], line 11, in Bank.__init__(self, pincode)
#       9 else:
#      10     self.min_bal =1000
# ---> 11 self.bal = self.deposit(self.min_bal)
#
# Cell In[31], line 13, in Bank.deposit(abc, bal)
#      12 def deposit(abc,bal):
# ---> 13     print("self in deposit is {}".format(self))
#      14     self.bal +=bal
#      15     return self.bal
#
# NameError: name 'self' is not defined

# %%
class Bank:
    def __init__(self,pincode):
        print("self in init is {}".format(self))
        self.pincode = pincode
        self.bal=0
        st_p =  self.pincode//100000
        if st_p <= 5:
            self.min_bal = 5000
        else:
            self.min_bal =1000
        self.bal = self.deposit(self.min_bal)
    def deposit(abc,bal):
        print("self in deposit is {}".format(abc))
        abc.bal +=bal
        return self.bal
b1 = Bank(500049)
# Out:
# self in init is <__main__.Bank object at 0x7871ff7a3970>
# self in deposit is <__main__.Bank object at 0x7871ff7a3970>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 16
#      14         abc.bal +=bal
#      15         return self.bal
# ---> 16 b1 = Bank(500049)
#
# Cell In[33], line 11, in Bank.__init__(self, pincode)
#       9 else:
#      10     self.min_bal =1000
# ---> 11 self.bal = self.deposit(self.min_bal)
#
# Cell In[33], line 15, in Bank.deposit(abc, bal)
#      13 print("self in deposit is {}".format(abc))
#      14 abc.bal +=bal
# ---> 15 return self.bal
#
# NameError: name 'self' is not defined

# %%
b1.deposit(10000)
# Out:
# self in deposit is <__main__.Bank object at 0x7871fe430ee0>
# 16000

# %%
class myclass:
    c = 30 #class varaiables
    d = 40
    def __init__(self,a,b):
        print("i am from init")
        self.b=a
        self.a=b

# %%
i1 =myclass(10,20)
i2=myclass(10,25)
# Out:
# i am from init
# i am from init

# %%
print(i1.a,i1.b,i1.c,i1.d)
# Out:
# 20 10 30 40

# %%
myclass.c=300

# %%
print(i1.a,i1.b,i1.c,i1.d)
# Out:
# 20 10 300 40

# %%
i1.c = 45
print(i1.a,i1.b,i1.c,i1.d)
print(i2.a,i2.b,i2.c,i2.d)
# Out:
# 20 10 45 40
# 25 10 300 40

# %%
i1.e=500
print(i1.a,i1.b,i1.c,i1.d,i1.e)
print(i2.a,i2.b,i2.c,i2.d,i2.e)
# Out:
# 20 10 45 40 500
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 3
#       1 i1.e=500
#       2 print(i1.a,i1.b,i1.c,i1.d,i1.e)
# ----> 3 print(i2.a,i2.b,i2.c,i2.d,i2.e)
#
# AttributeError: 'myclass' object has no attribute 'e'

# %%
class fraction():
    def __init__(self,num,denom):
        self.num = num
        self.denom = denom
    def display(self):
        return f"{self.num}/{self.denom}"

# %%
f1= fraction(5,3)
print(f1)

# %%
print(f1.display())
# Out:
# 5/3

# %%
class fraction():
    def __init__(self,num,denom):
        self.num = num
        self.denom = denom
    def __str__(self):
        return f"{self.num}/{self.denom}"
    def add(self,other):
        num = (self.num*other.denom)+(self.denom*other.num)
        denom = self.denom *other.denom
        return f"{num}/{denom}"
f1=fraction(5,3)
f2=fraction(2,8)

# %%
print(f1,f2)
# Out:
# 5/3 2/8

# %%
print(f1.add(f2))
# Out:
# 46/24

# %%
class fraction():
    def __init__(self,num,denom):
        self.num = num
        self.denom = denom
    def __str__(self):
        return f"{self.num}/{self.denom}"
    def __add__(self,other):
        num = (self.num*other.denom)+(self.denom*other.num)
        denom = self.denom *other.denom
        return f"{num}/{denom}"
f1=fraction(5,3)
f2=fraction(2,8)

# %%
f1+f2
# Out:
# '46/24'

# %%
class fraction():
    def __init__(self,num,denom):
        self.num = num
        self.denom = denom
    def __str__(self):
        return f"{self.num}/{self.denom}"
    def __add__(self,other):
        num = (self.num*other.denom)+(self.denom*other.num)
        denom = self.denom *other.denom
        #return f"{num}/{denom}"
        self.num = num
        self.denom = denom
f1=fraction(5,3)
f2=fraction(2,8)

# %%
print(f1+f2)
# Out:
# None

# %%
print(f1)
# Out:
# 46/24

# %%
class fraction():
    def __init__(self,num,denom):
        self.num = num
        self.denom = denom
    def __str__(self):
        return f"{self.num}/{self.denom}"
    @staticmethod
    def gcd(a,b):
        import math
        return math.gcd(a,b)
    def __add__(self,other):
        num = (self.num*other.denom)+(self.denom*other.num)
        denom = self.denom *other.denom
        #return f"{num}/{denom}"
        gcd_val=self.gcd(num,denom)
        num = num // gcd_val
        denom = num//gcd_val
        self .num = num
        self.denom = denom
f1=fraction(5,3)
f2=fraction(2,8)

# %%
f1+f2
print(f1)
# Out:
# 23/11

# %%
class fraction():
    frac = 10
    def __init__(self,num,denom):
        self.num = num/self.frac
        self.denom = denom/self.frac
        #return 100
    def __str__(self):
        return f"{self.num}/{self.denom}"
    @staticmethod
    def gcd(a,b):
        import math
        return math.gcd(a,b)
    @classmethod
    def change_frac(cls,val): 
        print(cls)
        gcd_val= cls.gcd(cls.frac,val)
        cls.frac = cls.frac+gcd_val
        
    def __add__(self,other):
        num = (self.num*other.denom)+(self.denom*other.num)
        denom = self.denom *other.denom
        #return f"{num}/{denom}"
        gcd_val=self.gcd(num,denom)
        num = num // gcd_val
        denom = num//gcd_val
        self .num = num
        self.denom = denom
f1=fraction(5,3)
f2=fraction(2,8)

# %%
class Myclass:
    def sum(self,*a):
        return sum(a)

# %%
a = Myclass()
a.sum(10,20,30,40)
# Out:
# 100

# %%
class parent:
    def __init__(self,a,b):
        self.a=a
        self.b=b
class child:
    def display(self):
        print(self.a,self.b)

# %%
p=parent(10,20)
p.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 2
#       1 p=parent(10,20)
# ----> 2 p.display()
#
# AttributeError: 'parent' object has no attribute 'display'

# %%
class parent:
    def __init__(self,a,b):
        self.a=a
        self.b=b
class child(parent):
    def display(self):
        print(self.a,self.b)

# %%
c = child(10,20)
c.display()
# Out:
# 10 20

# %%
class parent:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def display(self):
        print(self.a,self.b)
class child(parent):
    def __init__(self,a,b,c):
         self.a=a
         self.b=b
         self.c=c
    def display(self):
        print(self.a,self.b,self.c)
c = child(10,20,30)
c.display()
# Out:
# 10 20 30

# %%
class parent:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def display(self):
        return self.a,self.b
    def display1(self):
        return self.a,self.b*2
class child(parent):
    def __init__(self,a,b,c):
        super().__init__(a,b)
        self.c= self.display1()
    def display(self):
        print(self.a,self.b,self.c)
c = child(10,20,30)
c.display()
# Out:
# 10 20 (10, 40)

# %%
class parent:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def display(self):
        return self.a,self.b
    def display1(self):
        return self.a*2,self.b*2
class child(parent):
    def __init__(self,a,b,c):
        self.c= self.display1()
        super().__init__(a,b)
    def display(self):
        print(self.a,self.b,self.c)
c = child(10,20,30)
c.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 15
#      13     def display(self):
#      14         print(self.a,self.b,self.c)
# ---> 15 c = child(10,20,30)
#      16 c.display()
#
# Cell In[83], line 11, in child.__init__(self, a, b, c)
#      10 def __init__(self,a,b,c):
# ---> 11     self.c= self.display1()
#      12     super().__init__(a,b)
#
# Cell In[83], line 8, in parent.display1(self)
#       7 def display1(self):
# ----> 8     return self.a*2,self.b*2
#
# AttributeError: 'child' object has no attribute 'a'
